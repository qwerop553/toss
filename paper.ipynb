# %%
from scrap import load_candles

df = load_candles("005930", interval="1d")

# %%
import pandas as pd 
df['timestamp'].dt.date >= pd.Timestamp("2026-07-01")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 import pandas as pd
# ----> 2 df['timestamp'].dt.date >= pd.Timestamp("2026-07-01")
#
# File c:\Users\sungwon\miniconda3\envs\finance\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\sungwon\miniconda3\envs\finance\Lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File c:\Users\sungwon\miniconda3\envs\finance\Lib\site-packages\pandas\core\series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
# ...
